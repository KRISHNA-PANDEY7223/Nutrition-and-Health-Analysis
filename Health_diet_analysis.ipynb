# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\minup\Downloads\healthy_diet_calorie_intake.csv")

# %%
df.shape
# Out:
# (6000, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Person_ID                  6000 non-null   object
#  1   Age                        6000 non-null   int64
#  2   Gender                     6000 non-null   object
#  3   Height_cm                  6000 non-null   float64
#  4   Weight_kg                  6000 non-null   float64
#  5   BMI                        6000 non-null   float64
#  6   Activity_Level             6000 non-null   object
#  7   Daily_Calorie_Requirement  6000 non-null   int64
#  8   Daily_Calorie_Consumed     6000 non-null   int64
#  9   Protein_Intake_g           6000 non-null   float64
#  10  Carbohydrate_Intake_g      6000 non-null   float64
#  11  Fat_Intake_g               6000 non-null   float64
#  12  Water_Intake_Liters        6000 non-null   float64
#  13  Diet_Type                  6000 non-null   object
#  14  Health_Status              6000 non-null   object
# dtypes: float64(7), int64(3), object(5)
# memory usage: 703.3+ KB

# %%
df.head()
# Out:
#   Person_ID  Age  Gender  Height_cm  Weight_kg   BMI     Activity_Level  \
# 0     P0001   50    Male      176.4       74.8  24.0        Very Active
# 1     P0002   18  Female      167.6       75.5  26.9          Sedentary
# 2     P0003   68  Female      161.9       87.2  33.3     Lightly Active
# 3     P0004   22  Female      169.3       66.9  23.3  Moderately Active
# 4     P0005   30    Male      179.1       75.3  23.5          Sedentary
#
#    Daily_Calorie_Requirement  Daily_Calorie_Consumed  Protein_Intake_g  \
# 0                       2852                    2625             183.0
# 1                       1904                    2044              90.1
# 2                       2009                    2540             222.7
# 3                       2318                    2096              69.5
# 4                       2144                    1937              32.9
#
#    Carbohydrate_Intake_g  Fat_Intake_g  Water_Intake_Liters     Diet_Type  \
# 0                   16.9         202.8                  3.3          Keto
# 1                  306.5          50.8                  1.9         Vegan
# 2                  281.3          58.2                  2.4  High Protein
# 3                  299.8          68.7                  2.9      Balanced
# 4                  285.6          73.7                  2.2      Balanced
#
#   Health_Status
# 0       Healthy
# 1    Overweight
# 2         Obese
# 3       Healthy
# 4       Healthy

# %%
df.isna().sum()
# Out:
# Person_ID                    0
# Age                          0
# Gender                       0
# Height_cm                    0
# Weight_kg                    0
# BMI                          0
# Activity_Level               0
# Daily_Calorie_Requirement    0
# Daily_Calorie_Consumed       0
# Protein_Intake_g             0
# Carbohydrate_Intake_g        0
# Fat_Intake_g                 0
# Water_Intake_Liters          0
# Diet_Type                    0
# Health_Status                0
# dtype: int64

# %%
df.sample(10)
# Out:
#      Person_ID  Age  Gender  Height_cm  Weight_kg   BMI     Activity_Level  \
# 5237     P5238   52  Female      158.2       67.8  27.1          Sedentary
# 1842     P1843   41    Male      172.3       71.3  24.0        Very Active
# 4601     P4602   25  Female      161.1       64.5  24.9          Sedentary
# 5748     P5749   54   Other      164.1       80.6  29.9        Very Active
# 3983     P3984   37    Male      181.8       88.5  26.8     Lightly Active
# 4684     P4685   25  Female      159.6       62.7  24.6  Moderately Active
# 4639     P4640   60  Female      162.4       77.1  29.2     Lightly Active
# 5991     P5992   71  Female      161.6       73.1  28.0        Very Active
# 3351     P3352   40    Male      177.8       94.3  29.8  Moderately Active
# 5529     P5530   62    Male      179.6       80.3  24.9          Sedentary
#
#       Daily_Calorie_Requirement  Daily_Calorie_Consumed  Protein_Intake_g  \
# 5237                       1607                    1704              62.3
# 1842                       2825                    2705             111.0
# 4601                       1722                    1694              24.7
# 5748                       3162                    3644             185.4
# 3983                       2663                    2934             131.2
# 4684                       2191                    2226              73.8
# 4639                       1930                    2128              91.2
# 5991                       2271                    2394              80.7
# 3351                       3066                    3404             131.4
# 5529                       2009                    2126             109.1
#
#       Carbohydrate_Intake_g  Fat_Intake_g  Water_Intake_Liters   Diet_Type  \
# 5237                  253.0          49.2                  1.9  Vegetarian
# 1842                  380.1          82.3                  3.4       Vegan
# 4601                  252.6          65.0                  2.0    Balanced
# 5748                  468.8         114.1                  3.3  Vegetarian
# 3983                  367.6         104.3                  2.5  Vegetarian
# 4684                  316.5          73.9                  2.6    Balanced
# 4639                  322.0          52.8                  2.1       Vegan
# 5991                  385.3          58.9                  3.7       Vegan
# 3351                  491.2         101.5                  2.9    Balanced
# 5529                  301.6          53.7                  2.1       Vegan
#
#      Health_Status
# 5237    Overweight
# 1842       Healthy
# 4601       Healthy
# 5748    Overweight
# 3983    Overweight
# 4684       Healthy
# 4639    Overweight
# 5991    Overweight
# 3351    Overweight
# 5529       Healthy

# %%
df=df.drop_duplicates()

# %%
df.sample(10)
# Out:
#      Person_ID  Age  Gender  Height_cm  Weight_kg   BMI     Activity_Level  \
# 1783     P1784   20  Female      150.6       51.6  22.8  Moderately Active
# 1192     P1193   51    Male      160.9      103.5  40.0          Sedentary
# 831      P0832   75    Male      172.3       72.1  24.3     Lightly Active
# 3932     P3933   33  Female      167.3       55.8  19.9     Lightly Active
# 3112     P3113   39  Female      174.1       64.5  21.3        Very Active
# 4578     P4579   70   Other      161.3       82.7  31.8     Lightly Active
# 5058     P5059   28  Female      166.9       73.4  26.4        Very Active
# 2183     P2184   27    Male      168.3       84.1  29.7     Lightly Active
# 3373     P3374   27  Female      167.6       62.7  22.3  Moderately Active
# 4924     P4925   32    Male      182.6       83.9  25.2  Moderately Active
#
#       Daily_Calorie_Requirement  Daily_Calorie_Consumed  Protein_Intake_g  \
# 1783                       2022                    2129              56.0
# 1192                       2349                    3063             270.6
# 831                        2001                    2001             155.1
# 3932                       1841                    1694             138.4
# 3112                       2440                    2666             197.3
# 4578                       2427                    2765              62.9
# 5058                       2626                    3078             126.3
# 2183                       2570                    2934             267.2
# 3373                       2216                    2107              52.8
# 4924                       2956                    3259             130.9
#
#       Carbohydrate_Intake_g  Fat_Intake_g  Water_Intake_Liters      Diet_Type  \
# 1783                  281.2          86.7                  2.8  Mediterranean
# 1192                  340.5          68.8                  2.3   High Protein
# 831                   214.1          58.3                  2.2   High Protein
# 3932                  179.4          47.0                  2.4   High Protein
# 3112                  -19.2         217.0                  3.2           Keto
# 4578                  402.2         100.5                  2.5     Vegetarian
# 5058                  470.4          76.8                  3.4          Vegan
# 2183                  290.2          78.3                  2.6   High Protein
# 3373                  310.9          72.5                  2.5       Balanced
# 4924                  476.7          92.1                  3.0          Vegan
#
#      Health_Status
# 1783       Healthy
# 1192         Obese
# 831        Healthy
# 3932       Healthy
# 3112       Healthy
# 4578         Obese
# 5058    Overweight
# 2183    Overweight
# 3373       Healthy
# 4924    Overweight

# %%
df[df["Health_Status"]=="Healthy"].shape[0]
# Out:
# 2249

# %%
df[df["Health_Status"]=="Underweight"].shape[0]
# Out:
# 175

# %%
df[df["Health_Status"]=="Overweight"].shape[0]
# Out:
# 2500

# %%
df[df["Health_Status"]=="Obese"].shape[0]
# Out:
# 1076

# %%
df["Health_Status"].unique()
# Out:
# array(['Healthy', 'Overweight', 'Obese', 'Underweight'], dtype=object)

# %%
df["Diet_Type"].unique()
# Out:
# array(['Keto', 'Vegan', 'High Protein', 'Balanced', 'Mediterranean',
#        'Vegetarian'], dtype=object)

# %%
df[df["Diet_Type"]=="Keto"].shape[0]
# Out:
# 721

# %%
df[df["Diet_Type"]=="Vegan"].shape[0]
# Out:
# 585

# %%
df[df["Diet_Type"]=="High Protein"].shape[0]
# Out:
# 1076

# %%
df[df["Diet_Type"]=="Balanced"].shape[0]
# Out:
# 1536

# %%
df[df["Diet_Type"]=="Mediterranean"].shape[0]
# Out:
# 1027

# %%
df[df["Diet_Type"]=="Vegetarian"].shape[0]
# Out:
# 1055

# %%
((df["Diet_Type"] == "Vegetarian") & (df["Health_Status"] == "Healthy")).sum()
# Out:
# np.int64(404)

# %%
((df["Diet_Type"] == "Mediterranean") & (df["Health_Status"] == "Healthy")).sum()
# Out:
# np.int64(391)

# %%
pd.crosstab(
    df["Diet_Type"],
    df["Health_Status"]
)
# Out:
# Health_Status  Healthy  Obese  Overweight  Underweight
# Diet_Type
# Balanced           589    264         633           50
# High Protein       398    185         458           35
# Keto               257    136         309           19
# Mediterranean      391    183         420           33
# Vegan              210    122         238           15
# Vegetarian         404    186         442           23

# %%
pd.crosstab(
    df["Diet_Type"],
    df["Health_Status"],
    normalize= 'index'
)*100
# Out:
# Health_Status    Healthy      Obese  Overweight  Underweight
# Diet_Type
# Balanced       38.346354  17.187500   41.210938     3.255208
# High Protein   36.988848  17.193309   42.565056     3.252788
# Keto           35.644938  18.862691   42.857143     2.635229
# Mediterranean  38.072055  17.818890   40.895813     3.213242
# Vegan          35.897436  20.854701   40.683761     2.564103
# Vegetarian     38.293839  17.630332   41.895735     2.180095

# %%
pd.crosstab(
    df["Gender"],
    df["Health_Status"],
    normalize='index'
)*100
# Out:
# Health_Status    Healthy      Obese  Overweight  Underweight
# Gender
# Female         41.576182  15.796848   37.863398     4.763573
# Male           33.298755  20.020747   45.539419     1.141079
# Other          39.130435  18.181818   40.316206     2.371542

# %%
pd.crosstab(
    df["Gender"],
    df["Diet_Type"],
    normalize='index'
)*100
# Out:
# Diet_Type   Balanced  High Protein       Keto  Mediterranean      Vegan  \
# Gender
# Female     24.693520     17.793345  12.504378      18.038529   9.352014
# Male       26.175657     18.222683  11.514523      16.286307   9.958506
# Other      29.249012     16.205534  12.252964      16.205534  11.857708
#
# Diet_Type  Vegetarian
# Gender
# Female      17.618214
# Male        17.842324
# Other       14.229249

# %%
import seaborn as sns
import matplotlib.pyplot as plt

G_al = pd.crosstab(
    df["Gender"],
    df["Activity_Level"],
    normalize="index"
) * 100

activity_order = [
    "Sedentary",
    "Lightly Active",
    "Moderately Active",
    "Very Active",
    "Athlete"
]

G_al = G_al.reindex(columns=activity_order)

G_al.plot(kind="bar", stacked=True, figsize=(8, 5))

plt.title("Gender-wise Activity Level Distribution")
plt.xlabel("Gender")
plt.ylabel("Percentage")
plt.legend(title="Activity Level")
plt.tight_layout()
plt.show()

# %%
sns.countplot(
    data=df,
    x="Gender",
    hue="Activity_Level",
    hue_order=[
        "Sedentary",
        "Lightly Active",
        "Moderately Active",
        "Very Active",
        "Athlete"
    ]
)

plt.title("Gender-wise Activity Level")
plt.tight_layout()
plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#                                 Age  Height_cm  Weight_kg       BMI  \
# Age                        1.000000   0.003546   0.105740  0.109039
# Height_cm                  0.003546   1.000000   0.413814 -0.246448
# Weight_kg                  0.105740   0.413814   1.000000  0.775497
# BMI                        0.109039  -0.246448   0.775497  1.000000
# Daily_Calorie_Requirement -0.252781   0.517498   0.506589  0.178808
# Daily_Calorie_Consumed    -0.175597   0.364654   0.690917  0.477787
# Protein_Intake_g          -0.084040   0.176652   0.326290  0.223382
# Carbohydrate_Intake_g     -0.101428   0.218704   0.395661  0.265503
# Fat_Intake_g              -0.087563   0.170418   0.351608  0.254712
# Water_Intake_Liters       -0.023625   0.077350  -0.056858 -0.115819
#
#                            Daily_Calorie_Requirement  Daily_Calorie_Consumed  \
# Age                                        -0.252781               -0.175597
# Height_cm                                   0.517498                0.364654
# Weight_kg                                   0.506589                0.690917
# BMI                                         0.178808                0.477787
# Daily_Calorie_Requirement                   1.000000                0.908845
# Daily_Calorie_Consumed                      0.908845                1.000000
# Protein_Intake_g                            0.430931                0.468970
# Carbohydrate_Intake_g                       0.517020                0.570675
# Fat_Intake_g                                0.465744                0.513449
# Water_Intake_Liters                         0.660469                0.522339
#
#                            Protein_Intake_g  Carbohydrate_Intake_g  \
# Age                               -0.084040              -0.101428
# Height_cm                          0.176652               0.218704
# Weight_kg                          0.326290               0.395661
# BMI                                0.223382               0.265503
# Daily_Calorie_Requirement          0.430931               0.517020
# Daily_Calorie_Consumed             0.468970               0.570675
# Protein_Intake_g                   1.000000              -0.132679
# Carbohydrate_Intake_g             -0.132679               1.000000
# Fat_Intake_g                       0.253324              -0.300949
# Water_Intake_Liters                0.246838               0.291004
#
#                            Fat_Intake_g  Water_Intake_Liters
# Age                           -0.087563            -0.023625
# Height_cm                      0.170418             0.077350
# Weight_kg                      0.351608            -0.056858
# BMI                            0.254712            -0.115819
# Daily_Calorie_Requirement      0.465744             0.660469
# Daily_Calorie_Consumed         0.513449             0.522339
# Protein_Intake_g               0.253324             0.246838
# Carbohydrate_Intake_g         -0.300949             0.291004
# Fat_Intake_g                   1.000000             0.275897
# Water_Intake_Liters            0.275897             1.000000

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

gender_cal = df.groupby("Gender")[["Daily_Calorie_Requirement",
                                   "Daily_Calorie_Consumed"]].mean().reset_index()

gender_cal = gender_cal.melt(
    id_vars="Gender",
    var_name="Metric",
    value_name="Calories"
)

sns.barplot(
    data=gender_cal,
    x="Gender",
    y="Calories",
    hue="Metric"
)

plt.title("Average Calorie Intake vs Calories Consumed by Gender")
plt.show()

# %%
g_hs=pd.crosstab(
    df["Gender"],
    df["Health_Status"],
    normalize='index'
)*100

g_hs=g_hs[["Underweight","Healthy","Overweight","Obese"]]

sns.countplot(data=g_hs,x=df["Gender"],hue=df["Health_Status"])
plt.title("Gender wise Health Report")
plt.Figure(figsize=(10,6))
plt.tight_layout()
plt.show()

# %%
sns.regplot(data=df,x=df["Weight_kg"],y=df["BMI"],line_kws={"color": "yellow", "linewidth": 2,"linestyle":"--","alpha":0.6})
plt.title("weight wise bmi")
plt.show()

# %%
sns.lineplot(data=df,x=df["BMI"],y= df["Health_Status"],hue_order=["Underweight","Healthy","Overweight","Obese"],hue=df["Health_Status"])
plt.title("BMI vs Health_Status")
plt.show()

# %%
df[df["Water_Intake_Liters"]>2].shape[0]
# Out:
# 5100

# %%
sns.barplot(data=df,x=df["Gender"],y=df["Fat_Intake_g"],hue=df["Gender"])
plt.title("Fat intake by gender")
plt.show()

# %%
sns.barplot(data=df,x=df["Gender"],y=df["Protein_Intake_g"])
plt.title("Protein intake by gender")
plt.show()

# %%
df.groupby("Gender")[["Fat_Intake_g","Protein_Intake_g"]].mean()
# Out:
#         Fat_Intake_g  Protein_Intake_g
# Gender
# Female     81.330228        106.423678
# Male      104.695747        139.659820
# Other     107.559684        137.956917

# %%
df.groupby("Gender")[["Water_Intake_Liters","Weight_kg"]].mean()
# Out:
#         Water_Intake_Liters  Weight_kg
# Gender
# Female             2.715517  66.679405
# Male               2.751418  81.361584
# Other              2.765217  74.143083

# %%
df.groupby("Diet_Type")[["Fat_Intake_g","Protein_Intake_g"]].mean()
# Out:
#                Fat_Intake_g  Protein_Intake_g
# Diet_Type
# Balanced          82.748633         93.233529
# High Protein      68.909665        217.727045
# Keto             186.881137        154.658114
# Mediterranean     97.046446         94.371665
# Vegan             66.415385        100.914188
# Vegetarian        83.109763         92.601801

# %%
nutrients = (
    df.groupby("Diet_Type")[["Fat_Intake_g", "Protein_Intake_g"]].mean().reset_index()
)

nutrients_long = nutrients.melt(
    id_vars="Diet_Type",
    var_name="Nutrient",
    value_name="Average_Intake"
)

sns.barplot(
    data=nutrients_long,
    x="Diet_Type",
    y="Average_Intake",
    hue="Nutrient"
)

plt.title("Average Fat and Protein Intake by Diet Type")
plt.xticks(rotation=45)
plt.show()

# %%
pd.crosstab(
    df["Diet_Type"],
    df["Health_Status"],
    normalize= 'index'
)*100
# Out:
# Health_Status    Healthy      Obese  Overweight  Underweight
# Diet_Type
# Balanced       38.346354  17.187500   41.210938     3.255208
# High Protein   36.988848  17.193309   42.565056     3.252788
# Keto           35.644938  18.862691   42.857143     2.635229
# Mediterranean  38.072055  17.818890   40.895813     3.213242
# Vegan          35.897436  20.854701   40.683761     2.564103
# Vegetarian     38.293839  17.630332   41.895735     2.180095
